# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data={
    'name':['ravi','pranav','aman'],
    'age':[2,4,5]}
dataset=pd.DataFrame(data)

# %%
dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dataset
#
# NameError: name 'dataset' is not defined

# %%
datasets=pd.read_csv(r"C:\Users\sangharatna_2022\OneDrive\Desktop\Python\Python-Libraries\index_1.csv")
datasets.head(5)
# Out:
#          date                 datetime cash_type                 card  money  \
# 0  2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001   38.7
# 1  2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002   38.7
# 2  2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002   38.7
# 3  2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003   28.9
# 4  2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004   38.7
#
#      coffee_name
# 0          Latte
# 1  Hot Chocolate
# 2  Hot Chocolate
# 3      Americano
# 4          Latte

# %%
datasets.isnull().sum()
# Out:
# date            0
# datetime        0
# cash_type       0
# card           89
# money           0
# coffee_name     0
# dtype: int64

# %%
df=datasets.drop(columns=['datetime'],inplace=True)
df

# %%
datasets.shape
# Out:
# (3636, 5)

# %%
datasets.head(4)
# Out:
#          date cash_type                 card    coffee_name  new
# 0  2024-03-01      card  ANON-0000-0000-0001          Latte    0
# 1  2024-03-01      card  ANON-0000-0000-0002  Hot Chocolate    0
# 2  2024-03-01      card  ANON-0000-0000-0002  Hot Chocolate    0
# 3  2024-03-01      card  ANON-0000-0000-0003      Americano    0

# %%
from sklearn.preprocessing import LabelEncoder 
le=LabelEncoder()
datasets['new']=le.fit_transform(datasets['cash_type'])
datasets
# Out:
#             date                 datetime cash_type                 card  \
# 0     2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001
# 1     2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002
# 2     2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002
# 3     2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003
# 4     2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004
# ...          ...                      ...       ...                  ...
# 3631  2025-03-23  2025-03-23 10:34:54.894      card  ANON-0000-0000-1158
# 3632  2025-03-23  2025-03-23 14:43:37.362      card  ANON-0000-0000-1315
# 3633  2025-03-23  2025-03-23 14:44:16.864      card  ANON-0000-0000-1315
# 3634  2025-03-23  2025-03-23 15:47:28.723      card  ANON-0000-0000-1316
# 3635  2025-03-23  2025-03-23 18:11:38.635      card  ANON-0000-0000-1275
#
#         coffee_name  new
# 0             Latte    0
# 1     Hot Chocolate    0
# ...

# %%
datasets['cash_type'].unique()
# Out:
# array(['card', 'cash'], dtype=object)

# %%
datasets.shape
# Out:
# (3636, 6)

# %%
datasets.isnull().sum()
# Out:
# date            0
# datetime        0
# cash_type       0
# card           89
# coffee_name     0
# new             0
# dtype: int64

# %%
datasets.fillna(8)
# Out:
#             date                 datetime cash_type                 card  \
# 0     2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001
# 1     2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002
# 2     2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002
# 3     2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003
# 4     2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004
# ...          ...                      ...       ...                  ...
# 3631  2025-03-23  2025-03-23 10:34:54.894      card  ANON-0000-0000-1158
# 3632  2025-03-23  2025-03-23 14:43:37.362      card  ANON-0000-0000-1315
# 3633  2025-03-23  2025-03-23 14:44:16.864      card  ANON-0000-0000-1315
# 3634  2025-03-23  2025-03-23 15:47:28.723      card  ANON-0000-0000-1316
# 3635  2025-03-23  2025-03-23 18:11:38.635      card  ANON-0000-0000-1275
#
#       money    coffee_name
# 0     38.70          Latte
# 1     38.70  Hot Chocolate
# ...
